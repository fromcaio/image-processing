# %% [markdown]
# # Exercise 01: Foundations of Digital Images
#
# ### 🎯 Instructions
#
# This notebook contains theoretical and conceptual questions based on **Module 1: Introduction to Digital Image Processing**.
#
# Please answer each question in the Markdown cells provided below them. You don't need to write any code for this exercise, but you should think about the code we learned.

# %% [markdown]
# ---
#
# ### Question 1: Key Definitions
#
# In your own words, please define the following four terms:
#
# 1.  **Digital Image:**
# 2.  **Pixel:**
# 3.  **Sampling:**
# 4.  **Quantization:**

# %% [markdown]
# *(Write your answers here)*
#
# 1.  **Digital Image:** ...
# 2.  **Pixel:** ...
# 3.  **Sampling:** ...
# 4.  **Quantization:** ...

# %% [markdown]
# ---
#
# ### Question 2: Image Storage Calculation
#
# A new smartphone boasts a 48-megapixel camera (8000 x 6000 pixels). You take a photo, and it is saved as a 24-bit color image.
#
# **Calculate the uncompressed size of this single photograph in Megabytes (MB).**
#
# *Show your work.*
#
# *(Remember: 24 bits = 3 bytes. 1 MB = 1024 x 1024 bytes)*

# %% [markdown]
# *(Write your calculation and answer here)*
#
# 1.  **Dimensions (M, N):** 8000 x 6000 pixels
# 2.  **Bit Depth (k):** 24 bits per pixel
# 3.  **Total Pixels:** ...
# 4.  **Total Bits:** ...
# 5.  **Total Bytes:** ...
# 6.  **Total Megabytes:** ...

# %% [markdown]
# ---
#
# ### Question 3: Resolution and Artifacts
#
# Explain the difference between **Spatial Resolution** and **Intensity Resolution** (Bit Depth).
#
# For each, describe the visual artifact that occurs when the resolution is too low.
#
# 1.  **Spatial Resolution:**
#     * *What it is:* ...
#     * *Artifact when low:* ...
#
# 2.  **Intensity Resolution (Bit Depth):**
#     * *What it is:* ...
#     * *Artifact when low:* ...

# %% [markdown]
# *(Write your answers here)*

# %% [markdown]
# ---
#
# ### Question 4: The BGR vs. RGB Problem
#
# A fellow student writes the following code. They load an image of a person wearing a bright red shirt, but when they display it, the shirt looks bright *blue*.
#
# ```python
# # Student's code
# import cv2
# import matplotlib.pyplot as plt
#
# img = cv2.imread("path/to/my_image.jpg")
# plt.imshow(img)
# plt.title("Why are the colors wrong?")
# plt.show()
# ```
#
# 1.  **What is the *exact* cause of this problem?** (Why does `cv2` and `plt` clash?)
# 2.  **Write the *one line of code* that is missing** to fix this. Where would you add it?

# %% [markdown]
# *(Write your answers here)*
#
# 1.  **Cause:** ...
# 2.  **Missing line:** ...
#     **Where to add it:** ...

# %% [markdown]
# ---
#
# ### Question 5: Histogram Interpretation
#
# Below is a conceptual intensity histogram for an 8-bit grayscale image.
#
# *(Placeholder for Histogram Image)*
# > `[A histogram plot where the x-axis goes from 0 to 255. All the bars (the pixel counts) are clustered in a narrow range on the left, for example, between 20 and 80. The rest of the histogram from 80 to 255 is empty (zero).]`
#
# Based on this histogram, what can you tell about the image?
#
# 1.  **Contrast:** Is it a high-contrast or low-contrast image? Why?
# 2.  **Brightness:** Is it a bright image, a dark image, or well-balanced? Why?

# %% [markdown]
# *(Write your answers here)*
#
# 1.  **Contrast:** ...
# 2.  **Brightness:** ...
